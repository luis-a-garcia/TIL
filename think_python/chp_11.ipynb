# %%
from datetime import datetime

class Date:
    '''Represents a year, month, and day'''

    def make_date(date, date_format=("%Y-%m-%d")):
        s = f'The date is {date}. '
        print(s)

    def print_date(date):
        d = f'{date}'
        print(d)
    
    def is_after(d1, d2):
        d1
    
    def is_after(date1_str, date2_str, date_format="%Y-%m-%d"):

        try:
            date1 = datetime.strptime(date1_str, date_format)
            date2 = datetime.strptime(date2_str, date_format)
            earlier_date=min(date1, date2)
            later_date=max(date1, date2)
            print(f'{date2} is after {date1}')
        except ValueError as e:
            print(f"Error parsing dates: {e}")
            return None

# %%
Date.make_date("1933-06-22")
# Out:
# The date is 1933-06-22.

# %%
Date.print_date("1933-06-22")
# Out:
# 1933-06-22

# %%
Date.is_after('1933-06-22', '1933-09-17')
# Out:
# 1933-09-17 00:00:00 is after 1933-06-22 00:00:00
